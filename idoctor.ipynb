# %%
#*****PROBLEMATICA*****#
#Diferentes consultorios quieren mejorar su manera de diagnostico 
#medico debido a la alta demanda en analisis de tomografias.
#Debido a  esta problematica una solucion eficiente y rapida
#es dar respuesta a todos los pacientes que deseen ver su diagnostico
#atraves de esta plataforma y de esta manera enterarse de 
#su padecimiento en alguna de las enfermedades que se tratan :) 

#CODIGO
#Instalar los servicios de azure para utilizar vision IA
pip install --upgrade azure-cognitiveservices-vision-computervision
pip install pillow

#Importar librerias de cognitiveservices
from azure.cognitiveservices.vision.computervision import ComputerVisionClient
from azure.cognitiveservices.vision.computervision.models import OperationStatusCodes
from azure.cognitiveservices.vision.computervision.models import VisualFeatureTypes
from msrest.authentication import CognitiveServicesCredentials

from array import array
import os
from PIL,IPython.display import Image
import sys
import time

#declarar variables parametros de ComputerVisionClient
endpoint_url = 'idoctordiagnosis.cognitiveservices.azure.com'
key_url = '191K2MJD8123S9DK1230DA'

computervision_client = ComputerVisionClient(endpoint_url, CognitiveServicesCredentials(key_url))

#Ingresar URL de la tomografia para analizar
analisis_image_url = input('URL de la tomografia para analizar: ')
results = computervision_client.describe_image(analisis_image_url)
print('Analizando tomografia...')
#Verificar si existen captions de la tomografia
if(len(results.captions) == 0)
    print('No se detectaron descripciones')
else:
    #Guardar los tags de la tomografia
    Image(url=analisis_image_url)
    disaeses = [] 
    for tag in results.tags:
        if tag == "cancer"
            diseases.append("cancer")
        if tag == "derrame"
            diseases.append("derrame")
        if tag == "ascis"
            diseases.append("ascis")
    #Verificar con condiciones los resultados para responder al usuario 
    if(len(disaeses)>= 1)
        print("Enfermedades detectadas: ")
        for d in range(len(diseases)): 
        print(diseases[d])
        print("\n")
    else:
        print("No hay enfermedades detectadas, Felicidades!")
